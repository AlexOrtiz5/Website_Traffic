# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file
df = pd.read_csv("./Data/clean_website_wata.csv") 
df
# Out:
#       Page Views  Session Duration  Bounce Rate Traffic Source  Time on Page  \
# 0              4          3.429316     0.003910         social      8.478174
# 1              4          1.621052     0.003980        organic      9.636170
# 2              5          3.629279     0.001805        organic      2.071925
# 3              5          4.235843     0.002915           paid      1.960654
# 4              3          4.541868     0.004207         social      3.438712
# ...          ...               ...          ...            ...           ...
# 1883           9          3.577507     0.003522           paid      4.128122
# 1884           1          2.724513     0.002072       referral      1.324206
# 1885           3          0.392856     0.000956        organic      3.824416
# 1886           3          0.393319     0.002783           paid      5.037584
# 1887           3          0.882638     0.003380         direct      5.186908
#
#       Previous Visits  Conversion Rate
# ...

# %% [markdown]
# # Traffic source distribution

# %%
traffic_source_counts = df['Traffic Source'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=traffic_source_counts.index, y=traffic_source_counts.values)
plt.title('Traffic Source Distribution')
plt.xlabel('Traffic Source')
plt.ylabel('Number of Sessions')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Traffic source percentage distribution

# %%
plt.figure(figsize=(8,8))
plt.pie(traffic_source_counts, labels = traffic_source_counts.index, autopct='%1.1f%%')
plt.title("Percentage of traffic per source")
plt.show()

# %% [markdown]
# # Conversion rates per traffic source

# %%
conversion_rates = df.groupby('Traffic Source')['Conversion Rate'].mean().sort_values(ascending=False)
print("Conversion Rates by Traffic Source:\n", conversion_rates)
# Out:
# Conversion Rates by Traffic Source:
#  Traffic Source
# referral    0.009870
# social      0.009818
# organic     0.009812
# paid        0.009777
# direct      0.009776
# Name: Conversion Rate, dtype: float64
